# %% [markdown]
# <a href="https://colab.research.google.com/github/pavankalyan262005/PRODIGY_DS_01/blob/main/prodigy_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
population_data = pd.read_csv('/content/API_SP.POP.TOTL_DS2_en_csv_v2_31753.csv',skiprows=4)
countries = ['United States','India','China','Brazil','Nigeria','Germany','Japan']
year='2020'
plt.figure(figsize=(10,6))
plt.bar(population_2020['Country Name'], population_2020[year], color='green')
plt.xlabel('Country')
plt.ylabel('Population in 2020')
plt.title('Population of Selected Countries in 2020')
plt.show()
